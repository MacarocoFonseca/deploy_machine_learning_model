# %%
# !python -V
# Out:
# Python 3.9.16

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge

from sklearn.metrics import mean_squared_error

import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope



import pickle

# %%
import mlflow

# I need this because I am running with SQLite in the backend
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/Users/tdafonseca/Desktop/Github/learning/deploy_machine_learning_model/02-experiment-tracking/mlruns/2', creation_time=1686172186899, experiment_id='2', last_update_time=1686172186899, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df = pd.read_parquet("../data/green_tripdata_2023-01.parquet")

df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID','DOLocationID']
numerical = ['trip_distance']
df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')
  
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 7.059008426572675

# %%
sns.distplot(y_pred, label='prediction');
sns.distplot(y_train, label='actual');

plt.legend();
# Out:
# /var/folders/y1/h3rdxlrj2qvdwwjh6r3b721m0000gp/T/ipykernel_55088/851605343.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction');
# /var/folders/y1/h3rdxlrj2qvdwwjh6r3b721m0000gp/T/ipykernel_55088/851605343.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual');

# %%
def read_dataframe(filename):
    '''Data preprocessing
    '''
    df = pd.read_parquet(filename)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds()/60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID','DOLocationID']
    df[categorical] = df[categorical].astype(str)

    return df

# %%
df_train = read_dataframe('../data/green_tripdata_2023-01.parquet')
df_val = read_dataframe('../data/green_tripdata_2023-02.parquet')

# %%
len(df_train),len(df_val)
# Out:
# (65946, 62574)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO']#'PULocationID','DOLocationID']
numerical = ['trip_distance'] 

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
# target
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 6.034419810892012

# %%
lr = Lasso(alpha=0.001)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 6.742639978491274

# %%
lr = Ridge(alpha=0.001)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 6.028138722401977

# %%
with open('models/ling_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
# keep track of my ml experiments
with mlflow.start_run():
    
    mlflow.set_tag("developer","tomas")
    
    #parameters of the model and which data
    mlflow.log_param("train-data-path", "../data/green_tripdata_2023-01.parquet")
    mlflow.log_param("validation-data-path", "../data/green_tripdata_2023-02.parquet")
    
    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Ridge(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

# %% [markdown]
# #### Using XGboost

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    
    with mlflow.start_run():
        mlflow.set_tag("model","xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            # number of iterations
            num_boost_round=1000,
            # validation set
            evals=[(valid,"validation")],
            # Stop iteration if no optimization
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
    # Status ok = def if model runned ok
    return {'loss': rmse, 'status': STATUS_OK}

# %%
# ranges in which I want hyperopt to explore the hyper parameters
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)), #depth of trees
    'learning_rate': hp.loguniform('learning_rate', -3, 0), # learning rate range:[0.05, 1]
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1), 
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42,
}

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest, # optimization algo tpe
    max_evals=50,
    trials=Trials() # info. of each run
)
# Out:
# [19:32:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.17979
# [1]	validation-rmse:10.77738
# [2]	validation-rmse:9.02153
# [3]	validation-rmse:7.76706
# [4]	validation-rmse:6.89901
# [5]	validation-rmse:6.30912
# [6]	validation-rmse:5.92169
# [7]	validation-rmse:5.66660
# [8]	validation-rmse:5.50323
# [9]	validation-rmse:5.39761
# [10]	validation-rmse:5.33371
# [11]	validation-rmse:5.29410
# [12]	validation-rmse:5.26700
# [13]	validation-rmse:5.24684
# [14]	validation-rmse:5.23370
# [15]	validation-rmse:5.22595
# [16]	validation-rmse:5.21946
# [17]	validation-rmse:5.21450
# [18]	validation-rmse:5.21135
# [19]	validation-rmse:5.20987
# [20]	validation-rmse:5.20713
# [21]	validation-rmse:5.20547
# [22]	validation-rmse:5.20414
# [23]	validation-rmse:5.20270
# [24]	validation-rmse:5.20194
# [25]	validation-rmse:5.20010
# [26]	validation-rmse:5.19876
# [27]	validation-rmse:5.19767
# [28]	validation-rmse:5.19545
# [29]	validation-rmse:5.19355
# [30]	validation-rmse:5.19250
# [31]	validation-rmse:5.19178
# [32]	validation-rmse:5.19039
# [33]	validation-rmse:5.18994
# [34]	validation-rmse:5.18924
# [35]	validation-rmse:5.18923
# [36]	validation-rmse:5.18869
# [37]	validation-rmse:5.18673
# [38]	validation-rmse:5.18602
# [39]	validation-rmse:5.18565
# [40]	validation-rmse:5.18517
# [41]	validation-rmse:5.18394
# [42]	validation-rmse:5.18406
# [43]	validation-rmse:5.18316
# [44]	validation-rmse:5.18308
# [45]	validation-rmse:5.18265
# [46]	validation-rmse:5.18318
# [47]	validation-rmse:5.18250
# [48]	validation-rmse:5.18194
# [49]	validation-rmse:5.18139
# [50]	validation-rmse:5.18008
# [51]	validation-rmse:5.17928
# [52]	validation-rmse:5.17961
# [53]	validation-rmse:5.17813
# [54]	validation-rmse:5.17571
# [55]	validation-rmse:5.17560
# [56]	validation-rmse:5.17520
# [57]	validation-rmse:5.17547
# [58]	validation-rmse:5.17473
# [59]	validation-rmse:5.17440
# [60]	validation-rmse:5.17467
# [61]	validation-rmse:5.17397
# [62]	validation-rmse:5.17404
# [63]	validation-rmse:5.17329
# [64]	validation-rmse:5.17362
# [65]	validation-rmse:5.17163
# [66]	validation-rmse:5.17111
# [67]	validation-rmse:5.17088
# [68]	validation-rmse:5.17029
# [69]	validation-rmse:5.17015
# [70]	validation-rmse:5.16987
# [71]	validation-rmse:5.16996
# [72]	validation-rmse:5.16995
# [73]	validation-rmse:5.17018
# [74]	validation-rmse:5.17013
# [75]	validation-rmse:5.17075
# [76]	validation-rmse:5.17037
# [77]	validation-rmse:5.17004
# [78]	validation-rmse:5.17081
# [79]	validation-rmse:5.17036
# [80]	validation-rmse:5.16994
# [81]	validation-rmse:5.16864
# [82]	validation-rmse:5.16807
# [83]	validation-rmse:5.16757
# [84]	validation-rmse:5.16783
# [85]	validation-rmse:5.16602
# [86]	validation-rmse:5.16572
# [87]	validation-rmse:5.16565
# [88]	validation-rmse:5.16580
# [89]	validation-rmse:5.16664
# [90]	validation-rmse:5.16672
# [91]	validation-rmse:5.16741
# [92]	validation-rmse:5.16704
# [93]	validation-rmse:5.16756
# [94]	validation-rmse:5.16699
# [95]	validation-rmse:5.16716
# [96]	validation-rmse:5.16698
# [97]	validation-rmse:5.16699
# [98]	validation-rmse:5.16644
# [99]	validation-rmse:5.16601
# [100]	validation-rmse:5.16600
# [101]	validation-rmse:5.16573
# [102]	validation-rmse:5.16546
# [103]	validation-rmse:5.16579
# [104]	validation-rmse:5.16577
# [105]	validation-rmse:5.16570
# [106]	validation-rmse:5.16605
# [107]	validation-rmse:5.16605
# [108]	validation-rmse:5.16600
# [109]	validation-rmse:5.16542
# [110]	validation-rmse:5.16535
# [111]	validation-rmse:5.16533
# [112]	validation-rmse:5.16581
# [113]	validation-rmse:5.16545
# [114]	validation-rmse:5.16573
# [115]	validation-rmse:5.16488
# [116]	validation-rmse:5.16466
# [117]	validation-rmse:5.16432
# [118]	validation-rmse:5.16422
# [119]	validation-rmse:5.16450
# [120]	validation-rmse:5.16378
# [121]	validation-rmse:5.16380
# [122]	validation-rmse:5.16370
# [123]	validation-rmse:5.16316
# [124]	validation-rmse:5.16340
# [125]	validation-rmse:5.16327
# [126]	validation-rmse:5.16306
# [127]	validation-rmse:5.16296
# [128]	validation-rmse:5.16251
# [129]	validation-rmse:5.16233
# [130]	validation-rmse:5.16220
# [131]	validation-rmse:5.16223
# [132]	validation-rmse:5.16309
# [133]	validation-rmse:5.16306
# [134]	validation-rmse:5.16326
# [135]	validation-rmse:5.16364
# [136]	validation-rmse:5.16372
# [137]	validation-rmse:5.16384
# [138]	validation-rmse:5.16316
# [139]	validation-rmse:5.16460
# [140]	validation-rmse:5.16449
# [141]	validation-rmse:5.16486
# [142]	validation-rmse:5.16488
# [143]	validation-rmse:5.16492
# [144]	validation-rmse:5.16519
# [145]	validation-rmse:5.16515
# [146]	validation-rmse:5.16538
# [147]	validation-rmse:5.16546
# [148]	validation-rmse:5.16533
# [149]	validation-rmse:5.16602
# [150]	validation-rmse:5.16592
# [151]	validation-rmse:5.16597
# [152]	validation-rmse:5.16623
# [153]	validation-rmse:5.16618
# [154]	validation-rmse:5.16650
# [155]	validation-rmse:5.16678
# [156]	validation-rmse:5.16643
# [157]	validation-rmse:5.16676
# [158]	validation-rmse:5.16682
# [159]	validation-rmse:5.16703
# [160]	validation-rmse:5.16675
# [161]	validation-rmse:5.16545
# [162]	validation-rmse:5.16544
# [163]	validation-rmse:5.16556
# [164]	validation-rmse:5.16568
# [165]	validation-rmse:5.16559
# [166]	validation-rmse:5.16608
# [167]	validation-rmse:5.16554
# [168]	validation-rmse:5.16583
# [169]	validation-rmse:5.16611
# [170]	validation-rmse:5.16611
# [171]	validation-rmse:5.16628
# [172]	validation-rmse:5.16634
# [173]	validation-rmse:5.16639
# [174]	validation-rmse:5.16685
# [175]	validation-rmse:5.16713
# [176]	validation-rmse:5.16749
# [177]	validation-rmse:5.16763
# [178]	validation-rmse:5.16687
# [179]	validation-rmse:5.16681
# [19:32:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:9.36085
# [1]	validation-rmse:6.57430
# [2]	validation-rmse:5.66113
# [3]	validation-rmse:5.39032
# [4]	validation-rmse:5.30634
# [5]	validation-rmse:5.27017
# [6]	validation-rmse:5.25799
# [7]	validation-rmse:5.25279
# [8]	validation-rmse:5.24513
# [9]	validation-rmse:5.24005
# [10]	validation-rmse:5.23472
# [11]	validation-rmse:5.23019
# [12]	validation-rmse:5.22655
# [13]	validation-rmse:5.22478
# [14]	validation-rmse:5.22277
# [15]	validation-rmse:5.21748
# [16]	validation-rmse:5.21416
# [17]	validation-rmse:5.21159
# [18]	validation-rmse:5.21057
# [19]	validation-rmse:5.20888
# [20]	validation-rmse:5.20646
# [21]	validation-rmse:5.20454
# [22]	validation-rmse:5.20242
# [23]	validation-rmse:5.20025
# [24]	validation-rmse:5.19874
# [25]	validation-rmse:5.19763
# [26]	validation-rmse:5.19552
# [27]	validation-rmse:5.19428
# [28]	validation-rmse:5.19350
# [29]	validation-rmse:5.19241
# [30]	validation-rmse:5.19165
# [31]	validation-rmse:5.18990
# [32]	validation-rmse:5.18834
# [33]	validation-rmse:5.18748
# [34]	validation-rmse:5.18636
# [35]	validation-rmse:5.18325
# [36]	validation-rmse:5.18046
# [37]	validation-rmse:5.18084
# [38]	validation-rmse:5.17854
# [39]	validation-rmse:5.17876
# [40]	validation-rmse:5.17725
# [41]	validation-rmse:5.17576
# [42]	validation-rmse:5.17583
# [43]	validation-rmse:5.17268
# [44]	validation-rmse:5.17259
# [45]	validation-rmse:5.17194
# [46]	validation-rmse:5.17088
# [47]	validation-rmse:5.16992
# [48]	validation-rmse:5.16883
# [49]	validation-rmse:5.16967
# [50]	validation-rmse:5.16913
# [51]	validation-rmse:5.16857
# [52]	validation-rmse:5.16619
# [53]	validation-rmse:5.16597
# [54]	validation-rmse:5.16597
# [55]	validation-rmse:5.16570
# [56]	validation-rmse:5.16491
# [57]	validation-rmse:5.16276
# [58]	validation-rmse:5.16279
# [59]	validation-rmse:5.15993
# [60]	validation-rmse:5.15954
# [61]	validation-rmse:5.15924
# [62]	validation-rmse:5.16065
# [63]	validation-rmse:5.15693
# [64]	validation-rmse:5.15649
# [65]	validation-rmse:5.15623
# [66]	validation-rmse:5.15539
# [67]	validation-rmse:5.15584
# [68]	validation-rmse:5.15571
# [69]	validation-rmse:5.15499
# [70]	validation-rmse:5.15172
# [71]	validation-rmse:5.15131
# [72]	validation-rmse:5.15142
# [73]	validation-rmse:5.15031
# [74]	validation-rmse:5.14983
# [75]	validation-rmse:5.14912
# [76]	validation-rmse:5.14912
# [77]	validation-rmse:5.14904
# [78]	validation-rmse:5.14904
# [79]	validation-rmse:5.14859
# [80]	validation-rmse:5.14861
# [81]	validation-rmse:5.14820
# [82]	validation-rmse:5.14718
# [83]	validation-rmse:5.14700
# [84]	validation-rmse:5.14672
# [85]	validation-rmse:5.14604
# [86]	validation-rmse:5.14447
# [87]	validation-rmse:5.14435
# [88]	validation-rmse:5.14378
# [89]	validation-rmse:5.14369
# [90]	validation-rmse:5.14319
# [91]	validation-rmse:5.14409
# [92]	validation-rmse:5.14379
# [93]	validation-rmse:5.14364
# [94]	validation-rmse:5.14437
# [95]	validation-rmse:5.14421
# [96]	validation-rmse:5.14411
# [97]	validation-rmse:5.14331
# [98]	validation-rmse:5.14257
# ...
# [19:49:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:9.93260
# [1]	validation-rmse:6.98298
# [2]	validation-rmse:5.83146
# [3]	validation-rmse:5.44252
# [4]	validation-rmse:5.30769
# [5]	validation-rmse:5.26393
# [6]	validation-rmse:5.23813
# [7]	validation-rmse:5.22928
# [8]	validation-rmse:5.22499
# [9]	validation-rmse:5.21849
# [10]	validation-rmse:5.21529
# [11]	validation-rmse:5.21499
# [12]	validation-rmse:5.21183
# [13]	validation-rmse:5.20587
# [14]	validation-rmse:5.20341
# [15]	validation-rmse:5.20264
# [16]	validation-rmse:5.20168
# [17]	validation-rmse:5.20013
# [18]	validation-rmse:5.19935
# [19]	validation-rmse:5.19840
# [20]	validation-rmse:5.19628
# [21]	validation-rmse:5.19619
# [22]	validation-rmse:5.19423
# [23]	validation-rmse:5.19360
# [24]	validation-rmse:5.19247
# [25]	validation-rmse:5.19333
# [26]	validation-rmse:5.19320
# [27]	validation-rmse:5.19312
# [28]	validation-rmse:5.19224
# [29]	validation-rmse:5.19241
# [30]	validation-rmse:5.19183
# [31]	validation-rmse:5.18966
# [32]	validation-rmse:5.18973
# [33]	validation-rmse:5.19069
# [34]	validation-rmse:5.18964
# [35]	validation-rmse:5.18865
# [36]	validation-rmse:5.18838
# [37]	validation-rmse:5.18775
# [38]	validation-rmse:5.18615
# [39]	validation-rmse:5.18561
# [40]	validation-rmse:5.18526
# [41]	validation-rmse:5.18509
# [42]	validation-rmse:5.18615
# [43]	validation-rmse:5.18684
# [44]	validation-rmse:5.18685
# [45]	validation-rmse:5.18700
# [46]	validation-rmse:5.18767
# [47]	validation-rmse:5.18716
# [48]	validation-rmse:5.18770
# [49]	validation-rmse:5.18601
# [50]	validation-rmse:5.18568
# [51]	validation-rmse:5.19262
# [52]	validation-rmse:5.19328
# [53]	validation-rmse:5.19278
# [54]	validation-rmse:5.19341
# [55]	validation-rmse:5.19275
# [56]	validation-rmse:5.19221
# [57]	validation-rmse:5.19244
# [58]	validation-rmse:5.19361
# [59]	validation-rmse:5.19372
# [60]	validation-rmse:5.19486
# [61]	validation-rmse:5.19467
# [62]	validation-rmse:5.19412
# [63]	validation-rmse:5.19282
# [64]	validation-rmse:5.19335
# [65]	validation-rmse:5.19271
# [66]	validation-rmse:5.19345
# [67]	validation-rmse:5.19391
# [68]	validation-rmse:5.19366
# [69]	validation-rmse:5.19301
# [70]	validation-rmse:5.19340
# [71]	validation-rmse:5.19279
# [72]	validation-rmse:5.19365
# [73]	validation-rmse:5.19241
# [74]	validation-rmse:5.19429
# [75]	validation-rmse:5.19394
# [76]	validation-rmse:5.19473
# [77]	validation-rmse:5.19512
# [78]	validation-rmse:5.19457
# [79]	validation-rmse:5.19502
# [80]	validation-rmse:5.19577
# [81]	validation-rmse:5.19553
# [82]	validation-rmse:5.19546
# [83]	validation-rmse:5.19549
# [84]	validation-rmse:5.19709
# [85]	validation-rmse:5.19892
# [86]	validation-rmse:5.19862
# [87]	validation-rmse:5.19904
# [88]	validation-rmse:5.19876
# [89]	validation-rmse:5.19881
# [90]	validation-rmse:5.19887
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [17:13<00:00, 20.66s/trial, best loss: 5.110087914942558]

# %%
# train the model with best parameters (run name: upbeat-sponge-212)

params = {
    'learning_rate':0.1186097146922628,
    'max_depth': 10,
    'min_child_weight': 1.2670591294263422,
    'objective': 'reg:linear',
    'reg_alpha': 0.2726478524166285,
    'reg_lambda': 0.007451987452974171,
    'seed': 42    
}

mlflow.xgboost.autolog()
booster = xgb.train(
            params=params,
            dtrain=train,
            # number of iterations
            num_boost_round=1000,
            # validation set
            evals=[(valid,"validation")],
            # Stop iteration if no optimization
            early_stopping_rounds=50
        )
# Out:
# 2023/06/08 22:57:37 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2a3023ac5e1a4b5bb45e0c9796be7ee6', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [22:57:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.69938
# [1]	validation-rmse:13.21951
# [2]	validation-rmse:11.94221
# [3]	validation-rmse:10.84439
# [4]	validation-rmse:9.90415
# [5]	validation-rmse:9.10738
# [6]	validation-rmse:8.43356
# [7]	validation-rmse:7.86875
# [8]	validation-rmse:7.39857
# [9]	validation-rmse:7.00964
# [10]	validation-rmse:6.69105
# [11]	validation-rmse:6.42656
# [12]	validation-rmse:6.21347
# [13]	validation-rmse:6.04072
# [14]	validation-rmse:5.90193
# [15]	validation-rmse:5.78664
# [16]	validation-rmse:5.69627
# [17]	validation-rmse:5.62488
# [18]	validation-rmse:5.56618
# [19]	validation-rmse:5.51765
# [20]	validation-rmse:5.47823
# [21]	validation-rmse:5.44525
# [22]	validation-rmse:5.42182
# [23]	validation-rmse:5.40259
# [24]	validation-rmse:5.38675
# [25]	validation-rmse:5.37141
# [26]	validation-rmse:5.36083
# [27]	validation-rmse:5.34925
# [28]	validation-rmse:5.34171
